# %% [markdown]
# # Domain 2: Overtake Detection & Classification
#
# Analysis of overtake events detected via position-change methodology.

# %%
import pandas as pd
import numpy as np
from src.features.domain2_traffic import detect_overtakes
print("Imports OK")

# %% [markdown]
# ## Overtake Events

# %%
# Example: detect overtakes
laps = pd.DataFrame({"session_id": [1]*4, "driver": ["VER","VER","HAM","HAM"], "lap_number": [1,2,1,2], "position": [1,2,2,1], "track_status_cat": ["GREEN"]*4, "is_pit_lap": [0]*4})
result = detect_overtakes(laps)
print(result)
