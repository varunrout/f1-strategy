# %% [markdown]
# # Domain 2: Spatial Analysis — Hotspots & Bottlenecks
#
# Using DBSCAN clustering and density grids to identify overtaking hotspots and track bottlenecks.

# %%
import pandas as pd
import numpy as np
from src.features.domain2_traffic import detect_proximity_events, map_track_bottlenecks
print("Imports OK")

# %% [markdown]
# ## Proximity Events

# %%
# Proximity detection requires position data with x, y, z columns
print("See domain2_traffic.detect_proximity_events for API details")
