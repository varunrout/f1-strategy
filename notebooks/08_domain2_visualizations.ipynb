# %% [markdown]
# # Domain 2: Visualizations
#
# Visualization suite for traffic regimes, overtake hotspots, and bottleneck maps.

# %%
import pandas as pd
import numpy as np
try:
    import matplotlib.pyplot as plt
    import seaborn as sns
    print("Visualization libraries available")
except ImportError:
    print("Install matplotlib and seaborn for visualizations")

# %% [markdown]
# ## Traffic Regime Color Palette

# %%
REGIME_COLORS = {
    "CLEAN_AIR": "#2ecc71",
    "LIGHT_TRAFFIC": "#f1c40f",
    "MODERATE_TRAFFIC": "#e67e22",
    "HEAVY_TRAFFIC": "#e74c3c",
    "CLOSE_FOLLOWING": "#8e44ad",
}
print(REGIME_COLORS)
