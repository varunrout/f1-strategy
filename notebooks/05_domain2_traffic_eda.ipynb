# %% [markdown]
# # Domain 2: Traffic Regimes & Penalties — EDA
#
# This notebook explores traffic regime distribution and lap time penalties.

# %%
import pandas as pd
import numpy as np
from src.features.domain2_traffic import TRAFFIC_REGIMES, classify_traffic_regimes, quantify_traffic_penalties, summarise_traffic_penalties
print("Imports OK")

# %% [markdown]
# ## Traffic Regime Distribution

# %%
# Example: classify regimes on sample data
laps = pd.DataFrame({"session_id": [1]*4, "driver": ["VER"]*4, "lap_number": [1,2,3,4], "lap_time_s": [90.0,91.0,92.0,90.5], "gap_to_ahead_s": [5.0, 1.2, 0.8, 3.0]})
result = classify_traffic_regimes(laps, pd.DataFrame())
print(result[["lap_number","gap_to_ahead_s","traffic_regime"]])
